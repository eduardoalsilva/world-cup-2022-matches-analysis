# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoalsilva/world-cup-2022-matches-analysis/blob/main/soccer_world_cup_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri = "https://projects.fivethirtyeight.com/soccer-api/international/2022/wc_matches.csv"
matches = pd.read_csv(uri)

# %%
matches.head()
# Out:
#          date  league_id          league      team1         team2   spi1  \
# 0  2022-11-20       1908  FIFA World Cup      Qatar       Ecuador  51.00
# 1  2022-11-21       1908  FIFA World Cup    England          Iran  85.96
# 2  2022-11-21       1908  FIFA World Cup    Senegal   Netherlands  73.84
# 3  2022-11-21       1908  FIFA World Cup        USA         Wales  74.83
# 4  2022-11-22       1908  FIFA World Cup  Argentina  Saudi Arabia  87.21
#
#     spi2   prob1   prob2  probtie  proj_score1  proj_score2  score1  score2  \
# 0  72.74  0.2369  0.5045   0.2586         1.13         1.75       0       2
# 1  62.17  0.6274  0.1187   0.2539         1.70         0.58       6       2
# 2  86.01  0.2235  0.5053   0.2712         0.99         1.63       0       2
# 3  65.58  0.4489  0.2591   0.2920         1.42         1.01       1       1
# 4  56.87  0.7228  0.0807   0.1966         2.11         0.54       1       2
#
#     xg1   xg2  nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
matches.columns
# Out:
# Index(['date', 'league_id', 'league', 'team1', 'team2', 'spi1', 'spi2',
#        'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2', 'score1',
#        'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
sum(matches["score1"]) + sum(matches["score2"])
# Out:
# 172

# %%
matches['team1'].unique()
# Out:
# array(['Qatar', 'England', 'Senegal', 'USA', 'Argentina', 'Denmark',
#        'Mexico', 'France', 'Morocco', 'Germany', 'Spain', 'Belgium',
#        'Switzerland', 'Uruguay', 'Portugal', 'Brazil', 'Wales',
#        'Netherlands', 'Tunisia', 'Poland', 'Japan', 'Croatia', 'Cameroon',
#        'South Korea', 'Ecuador', 'Iran', 'Australia', 'Saudi Arabia',
#        'Canada', 'Costa Rica', 'Ghana', 'Serbia'], dtype=object)

# %%
matches.head()
# Out:
#          date  league_id          league      team1         team2   spi1  \
# 0  2022-11-20       1908  FIFA World Cup      Qatar       Ecuador  51.00
# 1  2022-11-21       1908  FIFA World Cup    England          Iran  85.96
# 2  2022-11-21       1908  FIFA World Cup    Senegal   Netherlands  73.84
# 3  2022-11-21       1908  FIFA World Cup        USA         Wales  74.83
# 4  2022-11-22       1908  FIFA World Cup  Argentina  Saudi Arabia  87.21
#
#     spi2   prob1   prob2  probtie  proj_score1  proj_score2  score1  score2  \
# 0  72.74  0.2369  0.5045   0.2586         1.13         1.75       0       2
# 1  62.17  0.6274  0.1187   0.2539         1.70         0.58       6       2
# 2  86.01  0.2235  0.5053   0.2712         0.99         1.63       0       2
# 3  65.58  0.4489  0.2591   0.2920         1.42         1.01       1       1
# 4  56.87  0.7228  0.0807   0.1966         2.11         0.54       1       2
#
#     xg1   xg2  nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
matches['total_score'] = matches['score1'] + matches['score2']

# %%
matches.head()
# Out:
#          date  league_id          league      team1         team2   spi1  \
# 0  2022-11-20       1908  FIFA World Cup      Qatar       Ecuador  51.00
# 1  2022-11-21       1908  FIFA World Cup    England          Iran  85.96
# 2  2022-11-21       1908  FIFA World Cup    Senegal   Netherlands  73.84
# 3  2022-11-21       1908  FIFA World Cup        USA         Wales  74.83
# 4  2022-11-22       1908  FIFA World Cup  Argentina  Saudi Arabia  87.21
#
#     spi2   prob1   prob2  probtie  ...  proj_score2  score1  score2   xg1  \
# 0  72.74  0.2369  0.5045   0.2586  ...         1.75       0       2  0.23
# 1  62.17  0.6274  0.1187   0.2539  ...         0.58       6       2  1.04
# 2  86.01  0.2235  0.5053   0.2712  ...         1.63       0       2  0.70
# 3  65.58  0.4489  0.2591   0.2920  ...         1.01       1       1  0.33
# 4  56.87  0.7228  0.0807   0.1966  ...         0.54       1       2  1.63
#
#     xg2  nsxg1  nsxg2  adj_score1  adj_score2  total_score
# ...

# %%
matches['total_score'].mean()
# Out:
# 2.6875

# %%
matches['total_score'].max()
# Out:
# 8

# %%
matches['score_difference'] = abs(matches['score1'] - matches['score2'])

# %%
matches['score_difference'].sum()
# Out:
# 90
